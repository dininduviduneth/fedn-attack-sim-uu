# %%
# HELPER FUNCTIONS

import collections

def get_mean_metrics(models, metric_type):
    mean_acc_fedavg = []
    for model in models["result"]:
        model_id = model["model"]
        validations = client.list_validations(modelId=model_id)

        acc = []
        for _, validation in validations.items(): 
            metrics = json.loads(validation['data'])
            if metric_type in metrics:
                acc.append(metrics[metric_type])

        if acc:
            mean_acc_fedavg.append(np.mean(acc))

    return np.min(mean_acc_fedavg) if 'loss' in metric_type else np.max(mean_acc_fedavg)

def get_baseline_metrics(baseline_session_id):
    models = client.list_models(baseline_session_id)

    baseline_metrics = {
        'training_loss': get_mean_metrics(models, 'training_loss'),
        'training_accuracy': get_mean_metrics(models, 'training_accuracy'),
        'test_loss': get_mean_metrics(models, 'test_loss'),
        'test_accuracy': get_mean_metrics(models, 'test_accuracy')
    }

    return baseline_metrics

# %%
from fedn import APIClient
import time
import uuid
import json
import matplotlib.pyplot as plt
import numpy as np
import collections

import sys
sys.path.append('/home/ubuntu/fedn-attack-sim-uu/examples/mnist-pytorch')

from combiner_config import COMBINER_IP

# %%
DISCOVER_HOST = COMBINER_IP
DISCOVER_PORT = 8092
client = APIClient(DISCOVER_HOST, DISCOVER_PORT)

# %%
[session['session_id'] for session in client.list_sessions()['result']]
# Out:
# ['BACKDOOR_TEST_04',
#  'BACKDOOR_TEST_03',
#  'BACKDOOR_TEST_02',
#  'BACKDOOR_TEST_01',
#  'MNIST_GBP100_25R_16_04',
#  'MNIST_GBP100_25R_18_02',
#  'MNIST_GBP100_25R_19_01',
#  'MNIST_GBP010_25R_16_04',
#  'MNIST_GBP010_25R_18_02',
#  'MNIST_GBP010_25R_19_01',
#  'MNIST_LFB_25R_16_04_V2',
#  'MNIST_LFB_25R_18_02_V2',
#  'MNIST_LFB_25R_19_01_V2',
#  'TEST_5_WITH_EPOCH_01',
#  'TEST_EPOCH_04',
#  'TEST_EPOCH_03',
#  'TEST_EPOCH_02',
#  'TEST_EPOCH_01',
#  'MNIST_GBM001_25R_18_02',
#  'MNIST_GBM001_25R_19_01',
#  'MNIST_BASE_25R_20_00']

# %%
session_id = input("Provide a session_id: ")
# Out:
# Provide a session_id:  BACKDOOR_TEST_04

# %%
# baseline_session_id = input("Provide baseline session_id: ")

# %%
baseline_metrics = get_baseline_metrics(input("Provide baseline session_id: "))
# Out:
# Provide baseline session_id:  MNIST_BASE_25R_20_00

# %%
models = client.list_models(session_id)
# models

# %%
num_rounds = models['count']
# num_rounds

# %%
# Provides a model trail for a given session (in FILO) --> need to be reversed
model_trail = models['result']
model_trail.reverse()
# model_trail

# %%
validations = []

for model_instance in model_trail:
    worker_results = client.list_validations(modelId=model_instance['model'])
    result_ids = [result_id for result_id in worker_results]
    for result_id in result_ids:
        worker_result = worker_results.get(result_id)
        client_type = 'benign'
        
        if 'malicious' in worker_result['sender']['name']:
            client_type = 'malicious'
            
        validation = {
            'model_committed_at': model_instance['committed_at'],
            'session_id': model_instance['session_id'],
            'model': model_instance['model'],
            'client_name': worker_result['sender']['name'],
            'client_role': worker_result['sender']['role'],
            'client_type': client_type,
            'training_loss': json.loads(worker_result['data'])['training_loss'],
            'training_accuracy': json.loads(worker_result['data'])['training_accuracy'],
            'test_loss': json.loads(worker_result['data'])['test_loss'],
            'test_accuracy': json.loads(worker_result['data'])['test_accuracy']
        }
        
        validations.append(validation)

# %%
# validations

# %%
# set([validation['client_name'] for validation in validations])

# %%
graph_data = {
    'training_loss': {
        client: {'data': [], 'type': client.split(sep='_')[0]} for client in set([validation['client_name'] for validation in validations])
    },
    'training_accuracy': {
        client: {'data': [], 'type': client.split(sep='_')[0]} for client in set([validation['client_name'] for validation in validations])
    },
    'test_loss': {
        client: {'data': [], 'type': client.split(sep='_')[0]} for client in set([validation['client_name'] for validation in validations])
    },
    'test_accuracy': {
        client: {'data': [], 'type': client.split(sep='_')[0]} for client in set([validation['client_name'] for validation in validations])
    },
    'overall_training_loss': [],
    'overall_training_accuracy': [],
    'overall_test_loss': [],
    'overall_test_accuracy': []
}

# %%
for validation in validations:
    graph_data['training_loss'][validation['client_name']]['data'].append(validation['training_loss'])
    graph_data['training_accuracy'][validation['client_name']]['data'].append(validation['training_accuracy'])
    graph_data['test_loss'][validation['client_name']]['data'].append(validation['test_loss'])
    graph_data['test_accuracy'][validation['client_name']]['data'].append(validation['test_accuracy'])

# %%
graph_data['overall_training_loss'] = [np.mean([graph_data['training_loss'][key]['data'][i] for key in graph_data['training_loss'].keys()]) for i in range(num_rounds)]
graph_data['overall_training_accuracy'] = [np.mean([graph_data['training_accuracy'][key]['data'][i] for key in graph_data['training_accuracy'].keys()]) for i in range(num_rounds)]
graph_data['overall_test_loss'] = [np.mean([graph_data['test_loss'][key]['data'][i] for key in graph_data['test_loss'].keys()]) for i in range(num_rounds)]
graph_data['overall_test_accuracy'] = [np.mean([graph_data['test_accuracy'][key]['data'][i] for key in graph_data['test_accuracy'].keys()]) for i in range(num_rounds)]

# %%
# graph_data

# %%
x = range(1, num_rounds + 1)
metric_type = "training_accuracy"

benign_counter = 0
malicious_counter = 0

# Plot actual data
for i in range(len(graph_data[metric_type])):
    if graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'benign':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='green', linestyle='--')
        benign_counter += 1
    elif graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'malicious':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='red', linestyle='--')
        malicious_counter += 1
    else:
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='black', linestyle='--')
    
plt.plot(x, graph_data[f'overall_{metric_type}'], color='black')

# Plot dummy lines with desired labels
plt.plot([], color='green', linestyle='--', label=f'{benign_counter} benign clients')
plt.plot([], color='red', linestyle='--', label=f'{malicious_counter} malicious clients')
plt.plot([], color='black', label=f'Overall {metric_type.replace("_", " ").title()}')

# Add a horizontal line for baseline max and overall max accuracies
if 'loss' in metric_type:
    plt.axhline(y=np.min(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Min {metric_type.replace("_", " ").title()}')
    plt.text(0, np.min(graph_data[f'overall_{metric_type}']), f'{np.min(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
else:
    plt.axhline(y=np.max(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Max {metric_type.replace("_", " ").title()}')
    plt.text(0, np.max(graph_data[f'overall_{metric_type}']), f'{np.max(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='top', color='red')
plt.axhline(y=baseline_metrics[metric_type], color='blue', linestyle='-.', label=f'Baseline {metric_type.replace("_", " ").title()}')

# Add text to y-axis
plt.text(0, baseline_metrics[metric_type], f'{baseline_metrics[metric_type]:.4f}', ha='left', va='bottom', color='blue')

# Add axis labels and title
plt.title(metric_type.replace("_", " ").title())
plt.xlabel(f'# of Rounds')
plt.ylabel(metric_type.replace("_", " ").title())

# Create legend with custom labels
plt.legend()
plt.grid(True, linestyle=':')
plt.xticks(np.arange(0, num_rounds + 1, 2))

plt.show()

# %%
x = range(1, num_rounds + 1)
metric_type = "test_accuracy"

benign_counter = 0
malicious_counter = 0

# Plot actual data
for i in range(len(graph_data[metric_type])):
    if graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'benign':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='green', linestyle='--')
        benign_counter += 1
    elif graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'malicious':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='red', linestyle='--')
        malicious_counter += 1
    else:
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='black', linestyle='--')
    
plt.plot(x, graph_data[f'overall_{metric_type}'], color='black')

# Plot dummy lines with desired labels
plt.plot([], color='green', linestyle='--', label=f'{benign_counter} benign clients')
plt.plot([], color='red', linestyle='--', label=f'{malicious_counter} malicious clients')
plt.plot([], color='black', label=f'Overall {metric_type.replace("_", " ").title()}')

# Add a horizontal line for baseline max and overall max accuracies
if 'loss' in metric_type:
    plt.axhline(y=np.min(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Min {metric_type.replace("_", " ").title()}')
    plt.text(0, np.min(graph_data[f'overall_{metric_type}']), f'{np.min(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
else:
    plt.axhline(y=np.max(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Max {metric_type.replace("_", " ").title()}')
    plt.text(0, np.max(graph_data[f'overall_{metric_type}']), f'{np.max(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='top', color='red')
plt.axhline(y=baseline_metrics[metric_type], color='blue', linestyle='-.', label=f'Baseline {metric_type.replace("_", " ").title()}')

# Add text to y-axis
plt.text(0, baseline_metrics[metric_type], f'{baseline_metrics[metric_type]:.4f}', ha='left', va='bottom', color='blue')

# Add axis labels and title
plt.title(metric_type.replace("_", " ").title())
plt.xlabel(f'# of Rounds')
plt.ylabel(metric_type.replace("_", " ").title())

# Create legend with custom labels
plt.legend()
plt.grid(True, linestyle=':')
plt.xticks(np.arange(0, num_rounds + 1, 2))

plt.show()

# %%
x = range(1, num_rounds + 1)
metric_type = "training_loss"

benign_counter = 0
malicious_counter = 0

# Plot actual data
for i in range(len(graph_data[metric_type])):
    if graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'benign':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='green', linestyle='--')
        benign_counter += 1
    elif graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'malicious':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='red', linestyle='--')
        malicious_counter += 1
    else:
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='black', linestyle='--')
    
plt.plot(x, graph_data[f'overall_{metric_type}'], color='black')

# Plot dummy lines with desired labels
plt.plot([], color='green', linestyle='--', label=f'{benign_counter} benign clients')
plt.plot([], color='red', linestyle='--', label=f'{malicious_counter} malicious clients')
plt.plot([], color='black', label=f'Overall {metric_type.replace("_", " ").title()}')

# Add a horizontal line for baseline max and overall max accuracies
if 'loss' in metric_type:
    plt.axhline(y=np.min(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Min {metric_type.replace("_", " ").title()}')
    plt.text(0, np.min(graph_data[f'overall_{metric_type}']), f'{np.min(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
else:
    plt.axhline(y=np.max(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Max {metric_type.replace("_", " ").title()}')
    plt.text(0, np.max(graph_data[f'overall_{metric_type}']), f'{np.max(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
plt.axhline(y=baseline_metrics[metric_type], color='blue', linestyle='-.', label=f'Baseline {metric_type.replace("_", " ").title()}')

# Add text to y-axis
plt.text(0, baseline_metrics[metric_type], f'{baseline_metrics[metric_type]:.4f}', ha='left', va='bottom', color='blue')

# Add axis labels and title
plt.title(metric_type.replace("_", " ").title())
plt.xlabel(f'# of Rounds')
plt.ylabel(metric_type.replace("_", " ").title())

# Create legend with custom labels
plt.legend()
plt.grid(True, linestyle=':')
plt.xticks(np.arange(0, num_rounds + 1, 2))

plt.show()

# %%
x = range(1, num_rounds + 1)
metric_type = "test_loss"

benign_counter = 0
malicious_counter = 0

# Plot actual data
for i in range(len(graph_data[metric_type])):
    if graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'benign':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='green', linestyle='--')
        benign_counter += 1
    elif graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['type'] == 'malicious':
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='red', linestyle='--')
        malicious_counter += 1
    else:
        plt.plot(x, graph_data[metric_type][list(graph_data[metric_type].keys())[i]]['data'], color='black', linestyle='--')
    
plt.plot(x, graph_data[f'overall_{metric_type}'], color='black')

# Plot dummy lines with desired labels
plt.plot([], color='green', linestyle='--', label=f'{benign_counter} benign clients')
plt.plot([], color='red', linestyle='--', label=f'{malicious_counter} malicious clients')
plt.plot([], color='black', label=f'Overall {metric_type.replace("_", " ").title()}')

# Add a horizontal line for baseline max and overall max accuracies
if 'loss' in metric_type:
    plt.axhline(y=np.min(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Min {metric_type.replace("_", " ").title()}')
    plt.text(0, np.min(graph_data[f'overall_{metric_type}']), f'{np.min(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
else:
    plt.axhline(y=np.max(graph_data[f'overall_{metric_type}']), color='red', linestyle='-.', label=f'Overall Max {metric_type.replace("_", " ").title()}')
    plt.text(0, np.max(graph_data[f'overall_{metric_type}']), f'{np.max(graph_data["overall_" + str(metric_type)]):.4f}', ha='left', va='bottom', color='red')
plt.axhline(y=baseline_metrics[metric_type], color='blue', linestyle='-.', label=f'Baseline {metric_type.replace("_", " ").title()}')

# Add text to y-axis
plt.text(0, baseline_metrics[metric_type], f'{baseline_metrics[metric_type]:.4f}', ha='left', va='bottom', color='blue')

# Add axis labels and title
plt.title(metric_type.replace("_", " ").title())
plt.xlabel(f'# of Rounds')
plt.ylabel(metric_type.replace("_", " ").title())

# Create legend with custom labels
plt.legend()
plt.grid(True, linestyle=':')
plt.xticks(np.arange(0, num_rounds + 1, 2))

plt.show()

# %%
client.list_validations(modelId=model_instance['model'])
# Out:
# {'66375a9d981afd046cebf052': {'data': '{"training_loss": 0.5612440705299377, "training_accuracy": 0.840666651725769, "test_loss": 0.5760403871536255, "test_accuracy": 0.8519999980926514, "train_target_misclassification": 0.22999999999999998, "test_target_misclassification": 0.25, "train_target_prediction_dist": [0, 12, 8, 14, 3, 10, 5, 2, 231, 15], "test_target_prediction_dist": [1, 2, 2, 1, 0, 3, 0, 2, 33, 0]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client6', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.799741Z'},
#  '66375a9d981afd046cebf053': {'data': '{"training_loss": 0.5354108214378357, "training_accuracy": 0.8516666889190674, "test_loss": 0.24223850667476654, "test_accuracy": 0.9620000123977661, "train_target_misclassification": 0.19999999999999996, "test_target_misclassification": 0.08333333333333337, "train_target_prediction_dist": [1, 12, 7, 15, 3, 6, 2, 5, 244, 10], "test_target_prediction_dist": [1, 1, 0, 0, 0, 1, 1, 0, 44, 0]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malicious_client2', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.817173Z'},
#  '66375a9d981afd046cebf054': {'data': '{"training_loss": 0.542907178401947, "training_accuracy": 0.8613333106040955, "test_loss": 0.503007709980011, "test_accuracy": 0.8560000061988831, "train_target_misclassification": 0.18214285714285716, "test_target_misclassification": 0.26190476190476186, "train_target_prediction_dist": [4, 9, 3, 10, 4, 8, 1, 1, 229, 11], "test_target_prediction_dist": [0, 1, 0, 1, 0, 2, 3, 0, 31, 4]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client14', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.820778Z'},
#  '66375a9d981afd046cebf055': {'data': '{"training_loss": 0.5258079171180725, "training_accuracy": 0.8646666407585144, "test_loss": 0.5441395044326782, "test_accuracy": 0.8600000143051147, "train_target_misclassification": 0.1839080459770115, "test_target_misclassification": 0.25, "train_target_prediction_dist": [1, 10, 2, 12, 1, 10, 6, 0, 213, 6], "test_target_prediction_dist": [1, 0, 0, 1, 1, 3, 0, 2, 30, 2]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client1', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.828159Z'},
#  '66375a9d981afd046cebf056': {'data': '{"training_loss": 0.541637122631073, "training_accuracy": 0.8539999723434448, "test_loss": 0.37577325105667114, "test_accuracy": 0.9240000247955322, "train_target_misclassification": 0.262987012987013, "test_target_misclassification": 0.10204081632653061, "train_target_prediction_dist": [1, 17, 10, 18, 5, 12, 1, 3, 227, 14], "test_target_prediction_dist": [0, 0, 1, 0, 0, 1, 0, 1, 44, 2]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client15', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.828776Z'},
#  '66375a9d981afd046cebf057': {'data': '{"training_loss": 0.5576937794685364, "training_accuracy": 0.8569999933242798, "test_loss": 0.3881612718105316, "test_accuracy": 0.8880000114440918, "train_target_misclassification": 0.17229729729729726, "test_target_misclassification": 0.24444444444444446, "train_target_prediction_dist": [3, 4, 1, 19, 0, 10, 3, 5, 245, 6], "test_target_prediction_dist": [1, 0, 0, 0, 3, 4, 2, 0, 34, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malicious_client1', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.798189Z'},
#  '66375a9d981afd046cebf058': {'data': '{"training_loss": 0.4403802752494812, "training_accuracy": 0.8980000019073486, "test_loss": 0.6166899800300598, "test_accuracy": 0.8320000171661377, "train_target_misclassification": 0.15488215488215484, "test_target_misclassification": 0.25, "train_target_prediction_dist": [5, 9, 1, 9, 1, 9, 2, 4, 251, 6], "test_target_prediction_dist": [0, 3, 1, 3, 2, 1, 0, 0, 36, 2]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malicious_client4', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.839266Z'},
#  '66375a9d981afd046cebf059': {'data': '{"training_loss": 0.513657808303833, "training_accuracy": 0.8666666746139526, "test_loss": 0.5193084478378296, "test_accuracy": 0.8640000224113464, "train_target_misclassification": 0.20618556701030932, "test_target_misclassification": 0.2666666666666667, "train_target_prediction_dist": [0, 8, 7, 11, 2, 12, 1, 4, 231, 15], "test_target_prediction_dist": [0, 0, 0, 6, 0, 2, 0, 3, 33, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client7', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.841273Z'},
#  '66375a9d981afd046cebf05a': {'data': '{"training_loss": 0.6041722297668457, "training_accuracy": 0.8420000076293945, "test_loss": 0.3401050865650177, "test_accuracy": 0.9200000166893005, "train_target_misclassification": 0.25, "test_target_misclassification": 0.19999999999999996, "train_target_prediction_dist": [0, 16, 7, 17, 6, 14, 5, 1, 225, 9], "test_target_prediction_dist": [0, 1, 0, 1, 2, 2, 0, 1, 40, 3]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client11', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.841410Z'},
#  '66375a9d981afd046cebf05b': {'data': '{"training_loss": 0.501340389251709, "training_accuracy": 0.8713333606719971, "test_loss": 0.4575558304786682, "test_accuracy": 0.878000020980835, "train_target_misclassification": 0.1515151515151515, "test_target_misclassification": 0.22916666666666663, "train_target_prediction_dist": [1, 3, 4, 13, 1, 6, 1, 2, 252, 14], "test_target_prediction_dist": [0, 0, 1, 1, 5, 3, 1, 0, 37, 0]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client12', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.844592Z'},
#  '66375a9d981afd046cebf05c': {'data': '{"training_loss": 0.5462141633033752, "training_accuracy": 0.8579999804496765, "test_loss": 0.5921035408973694, "test_accuracy": 0.843999981880188, "train_target_misclassification": 0.2233676975945017, "test_target_misclassification": 0.3207547169811321, "train_target_prediction_dist": [1, 10, 2, 15, 2, 12, 4, 2, 226, 17], "test_target_prediction_dist": [1, 1, 1, 4, 3, 0, 2, 2, 36, 3]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client10', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.852728Z'},
#  '66375a9d981afd046cebf065': {'data': '{"training_loss": 0.5402368307113647, "training_accuracy": 0.8573333621025085, "test_loss": 0.635610818862915, "test_accuracy": 0.828000009059906, "train_target_misclassification": 0.24315068493150682, "test_target_misclassification": 0.21153846153846156, "train_target_prediction_dist": [2, 18, 2, 18, 2, 10, 6, 2, 221, 11], "test_target_prediction_dist": [1, 0, 0, 3, 1, 3, 1, 1, 41, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client9', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.857225Z'},
#  '66375a9d981afd046cebf069': {'data': '{"training_loss": 0.540505588054657, "training_accuracy": 0.8519999980926514, "test_loss": 0.4238845705986023, "test_accuracy": 0.9020000100135803, "train_target_misclassification": 0.23958333333333337, "test_target_misclassification": 0.1132075471698113, "train_target_prediction_dist": [1, 10, 5, 20, 3, 15, 1, 3, 219, 11], "test_target_prediction_dist": [0, 0, 0, 2, 0, 0, 1, 0, 47, 3]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client13', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.861391Z'},
#  '66375a9d981afd046cebf06a': {'data': '{"training_loss": 0.4895710349082947, "training_accuracy": 0.8713333606719971, "test_loss": 0.37891000509262085, "test_accuracy": 0.9160000085830688, "train_target_misclassification": 0.22999999999999998, "test_target_misclassification": 0.10869565217391308, "train_target_prediction_dist": [3, 17, 11, 15, 0, 11, 0, 3, 231, 9], "test_target_prediction_dist": [0, 0, 0, 1, 1, 2, 0, 0, 41, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'malicious_client3', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.861561Z'},
#  '66375a9d981afd046cebf06c': {'data': '{"training_loss": 0.549061119556427, "training_accuracy": 0.8473333120346069, "test_loss": 0.44576069712638855, "test_accuracy": 0.8840000033378601, "train_target_misclassification": 0.26885245901639343, "test_target_misclassification": 0.1785714285714286, "train_target_prediction_dist": [6, 17, 6, 22, 1, 15, 2, 1, 223, 12], "test_target_prediction_dist": [1, 1, 0, 2, 0, 5, 0, 0, 46, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client16', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.875234Z'},
#  '66375a9d981afd046cebf06d': {'data': '{"training_loss": 0.4991731643676758, "training_accuracy": 0.8656666874885559, "test_loss": 0.6916075348854065, "test_accuracy": 0.8119999766349792, "train_target_misclassification": 0.19330855018587356, "test_target_misclassification": 0.24528301886792447, "train_target_prediction_dist": [1, 11, 3, 10, 1, 12, 7, 1, 217, 6], "test_target_prediction_dist": [0, 2, 1, 4, 0, 5, 0, 0, 40, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client8', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.875375Z'},
#  '66375a9d981afd046cebf06e': {'data': '{"training_loss": 0.5507058501243591, "training_accuracy": 0.8576666712760925, "test_loss": 0.6615527868270874, "test_accuracy": 0.8140000104904175, "train_target_misclassification": 0.24745762711864405, "test_target_misclassification": 0.27450980392156865, "train_target_prediction_dist": [6, 12, 7, 17, 2, 10, 8, 1, 222, 10], "test_target_prediction_dist": [1, 2, 1, 2, 2, 3, 1, 0, 37, 2]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client3', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.875365Z'},
#  '66375a9d981afd046cebf06f': {'data': '{"training_loss": 0.5115200877189636, "training_accuracy": 0.8679999709129333, "test_loss": 0.5523563623428345, "test_accuracy": 0.8679999709129333, "train_target_misclassification": 0.21724137931034482, "test_target_misclassification": 0.30612244897959184, "train_target_prediction_dist": [1, 12, 4, 19, 2, 7, 4, 3, 227, 11], "test_target_prediction_dist": [0, 0, 1, 4, 1, 3, 2, 1, 34, 3]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client2', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.876110Z'},
#  '66375a9d981afd046cebf070': {'data': '{"training_loss": 0.5180501937866211, "training_accuracy": 0.8616666793823242, "test_loss": 0.6385862827301025, "test_accuracy": 0.8259999752044678, "train_target_misclassification": 0.25266903914590744, "test_target_misclassification": 0.3076923076923077, "train_target_prediction_dist": [2, 9, 6, 14, 9, 16, 4, 1, 210, 10], "test_target_prediction_dist": [1, 3, 2, 3, 0, 3, 1, 2, 36, 1]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client4', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.876309Z'},
#  '66375a9d981afd046cebf075': {'data': '{"training_loss": 0.5819841027259827, "training_accuracy": 0.8399999737739563, "test_loss": 0.6760453581809998, "test_accuracy": 0.7979999780654907, "train_target_misclassification": 0.24590163934426235, "test_target_misclassification": 0.36, "train_target_prediction_dist": [1, 10, 2, 28, 4, 15, 1, 2, 230, 12], "test_target_prediction_dist": [2, 3, 0, 6, 2, 1, 0, 1, 32, 3]}',
#   'meta': '',
#   'model_id': 'c32b250f-2edd-4e1f-8a83-64379ae4ab3f',
#   'receiver': {'name': 'combiner', 'role': 'COMBINER'},
#   'sender': {'name': 'benign_client5', 'role': 'WORKER'},
#   'timestamp': '2024-05-05T10:08:29.877047Z'}}

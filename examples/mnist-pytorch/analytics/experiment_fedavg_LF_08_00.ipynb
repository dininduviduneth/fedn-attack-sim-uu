# %%
from fedn import APIClient
import time
import uuid
import json
import matplotlib.pyplot as plt
import numpy as np
import collections

# %%
DISCOVER_HOST = '10.0.0.4'
DISCOVER_PORT = 8092
client = APIClient(DISCOVER_HOST, DISCOVER_PORT)

# %%
[session['session_id'] for session in client.list_sessions()['result']]
# Out:
# ['experiment_fedavg_LF_05_03',
#  'experiment_fedavg_LF_08_00',
#  'experiment_fedavg_LF_06_02',
#  'experiment_fedavg_LF_07_01']

# %%
session_id = input("Provide a session_id: ")
# Out:
# Provide a session_id:  experiment_fedavg_LF_08_00

# %%
models = client.list_models(session_id)
# models

# %%
num_rounds = models['count']
# num_rounds

# %%
# Provides a model trail for a given session (in FILO) --> need to be reversed
model_trail = models['result']
model_trail.reverse()
# model_trail

# %%
validations = []

for model_instance in model_trail:
    worker_results = client.list_validations(modelId=model_instance['model'])
    result_ids = [result_id for result_id in worker_results]
    for result_id in result_ids:
        worker_result = worker_results.get(result_id)
        client_type = 'benign'
        
        if 'malicious' in worker_result['sender']['name']:
            client_type = 'malicious'
            
        validation = {
            'model_committed_at': model_instance['committed_at'],
            'session_id': model_instance['session_id'],
            'model': model_instance['model'],
            'client_name': worker_result['sender']['name'],
            'client_role': worker_result['sender']['role'],
            'client_type': client_type,
            'training_loss': json.loads(worker_result['data'])['training_loss'],
            'training_accuracy': json.loads(worker_result['data'])['training_accuracy'],
            'test_loss': json.loads(worker_result['data'])['test_loss'],
            'test_accuracy': json.loads(worker_result['data'])['test_accuracy']
        }
        
        validations.append(validation)

# %%
# validations

# %%
# set([validation['client_name'] for validation in validations])
# Out:
# {'benign_client1',
#  'benign_client2',
#  'benign_client3',
#  'benign_client4',
#  'malicious_client1',
#  'malicious_client2'}

# %%
# validations
# Out:
# [{'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 1.5673645734786987,
#   'training_accuracy': 0.7738000154495239,
#   'test_loss': 1.6268917322158813,
#   'test_accuracy': 0.7262905240058899},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 1.548387050628662,
#   'training_accuracy': 0.7853999733924866,
#   'test_loss': 1.6311389207839966,
#   'test_accuracy': 0.7280912399291992},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 1.5774943828582764,
#   'training_accuracy': 0.7670999765396118,
#   'test_loss': 1.4714856147766113,
#   'test_accuracy': 0.8163265585899353},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 1.5674965381622314,
#   'training_accuracy': 0.7674000263214111,
#   'test_loss': 1.4711287021636963,
#   'test_accuracy': 0.8271308541297913},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 1.5551762580871582,
#   'training_accuracy': 0.765500009059906,
#   'test_loss': 1.6254440546035767,
#   'test_accuracy': 0.732893168926239},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:12 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '1836db54-1b37-4781-b757-745caaf3068c',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 1.5464024543762207,
#   'training_accuracy': 0.7940999865531921,
#   'test_loss': 1.4725028276443481,
#   'test_accuracy': 0.8331332802772522},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.5775647759437561,
#   'training_accuracy': 0.8669000267982483,
#   'test_loss': 0.6671116948127747,
#   'test_accuracy': 0.837334930896759},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.5311733484268188,
#   'training_accuracy': 0.8853999972343445,
#   'test_loss': 0.4385134279727936,
#   'test_accuracy': 0.9171668887138367},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.5582768321037292,
#   'training_accuracy': 0.871999979019165,
#   'test_loss': 0.6477159857749939,
#   'test_accuracy': 0.8463385105133057},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.5902866721153259,
#   'training_accuracy': 0.8654000163078308,
#   'test_loss': 0.4516389071941376,
#   'test_accuracy': 0.9051620364189148},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.5674248337745667,
#   'training_accuracy': 0.8693000078201294,
#   'test_loss': 0.6677106618881226,
#   'test_accuracy': 0.8283313512802124},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:34:45 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'cb80f0dc-2cb7-4f00-af92-71a702673629',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.575085461139679,
#   'training_accuracy': 0.8655999898910522,
#   'test_loss': 0.4438140392303467,
#   'test_accuracy': 0.9129651784896851},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.42392241954803467,
#   'training_accuracy': 0.8830999732017517,
#   'test_loss': 0.31093165278434753,
#   'test_accuracy': 0.9171668887138367},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.39825162291526794,
#   'training_accuracy': 0.8931000232696533,
#   'test_loss': 0.4658801853656769,
#   'test_accuracy': 0.8745498061180115},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.4068688154220581,
#   'training_accuracy': 0.8902999758720398,
#   'test_loss': 0.49942901730537415,
#   'test_accuracy': 0.8577430844306946},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.4142305552959442,
#   'training_accuracy': 0.8881999850273132,
#   'test_loss': 0.4909250736236572,
#   'test_accuracy': 0.8619447946548462},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.40935570001602173,
#   'training_accuracy': 0.8860999941825867,
#   'test_loss': 0.28922343254089355,
#   'test_accuracy': 0.9267706871032715},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:16 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '96703468-6f40-45e5-84b6-b102e378e1dc',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.36608338356018066,
#   'training_accuracy': 0.906000018119812,
#   'test_loss': 0.289307177066803,
#   'test_accuracy': 0.9357743263244629},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3348609507083893,
#   'training_accuracy': 0.9049000144004822,
#   'test_loss': 0.3952290415763855,
#   'test_accuracy': 0.8865545988082886},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.3436823785305023,
#   'training_accuracy': 0.8977000117301941,
#   'test_loss': 0.2307661920785904,
#   'test_accuracy': 0.9357743263244629},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.36083540320396423,
#   'training_accuracy': 0.8962000012397766,
#   'test_loss': 0.2549150288105011,
#   'test_accuracy': 0.9285714030265808},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.35229620337486267,
#   'training_accuracy': 0.9007999897003174,
#   'test_loss': 0.4168582856655121,
#   'test_accuracy': 0.8805522322654724},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3444003760814667,
#   'training_accuracy': 0.9006999731063843,
#   'test_loss': 0.4313136041164398,
#   'test_accuracy': 0.8697478771209717},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:35:48 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e2edf411-05f8-4ab7-b6f3-a3afb90bcce5',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.3023568093776703,
#   'training_accuracy': 0.9143000245094299,
#   'test_loss': 0.23362143337726593,
#   'test_accuracy': 0.9387755393981934},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3186076879501343,
#   'training_accuracy': 0.9074000120162964,
#   'test_loss': 0.38082870841026306,
#   'test_accuracy': 0.8889555931091309},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.30384936928749084,
#   'training_accuracy': 0.9128999710083008,
#   'test_loss': 0.36027055978775024,
#   'test_accuracy': 0.8943577408790588},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.3099632263183594,
#   'training_accuracy': 0.906499981880188,
#   'test_loss': 0.2010803520679474,
#   'test_accuracy': 0.942376971244812},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.27073386311531067,
#   'training_accuracy': 0.9226999878883362,
#   'test_loss': 0.2085375040769577,
#   'test_accuracy': 0.9453781247138977},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3296704888343811,
#   'training_accuracy': 0.90420001745224,
#   'test_loss': 0.2260923832654953,
#   'test_accuracy': 0.9387755393981934},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:19 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': 'e29c0465-19d1-4140-bd80-a9f02d995d4d',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3164752721786499,
#   'training_accuracy': 0.9074000120162964,
#   'test_loss': 0.3987351059913635,
#   'test_accuracy': 0.8823529481887817},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.28164079785346985,
#   'training_accuracy': 0.913100004196167,
#   'test_loss': 0.18048815429210663,
#   'test_accuracy': 0.9459784030914307},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.276668906211853,
#   'training_accuracy': 0.9197999835014343,
#   'test_loss': 0.3276730179786682,
#   'test_accuracy': 0.8997598886489868},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.24394164979457855,
#   'training_accuracy': 0.9279999732971191,
#   'test_loss': 0.18695318698883057,
#   'test_accuracy': 0.9489796161651611},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.3005332946777344,
#   'training_accuracy': 0.9110000133514404,
#   'test_loss': 0.20532317459583282,
#   'test_accuracy': 0.9399759769439697},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2897506356239319,
#   'training_accuracy': 0.9142000079154968,
#   'test_loss': 0.36457619071006775,
#   'test_accuracy': 0.8883553147315979},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:36:53 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '36274757-1772-4574-8089-c82ee20135cb',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2909184694290161,
#   'training_accuracy': 0.916100025177002,
#   'test_loss': 0.34702640771865845,
#   'test_accuracy': 0.8979591727256775},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2761128544807434,
#   'training_accuracy': 0.9178000092506409,
#   'test_loss': 0.3474552035331726,
#   'test_accuracy': 0.8889555931091309},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2849964201450348,
#   'training_accuracy': 0.9150000214576721,
#   'test_loss': 0.1894935965538025,
#   'test_accuracy': 0.9447779059410095},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.26317453384399414,
#   'training_accuracy': 0.9186999797821045,
#   'test_loss': 0.1616019755601883,
#   'test_accuracy': 0.953181266784668},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2601196765899658,
#   'training_accuracy': 0.9240000247955322,
#   'test_loss': 0.3117944300174713,
#   'test_accuracy': 0.9027611017227173},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.22661474347114563,
#   'training_accuracy': 0.9332000017166138,
#   'test_loss': 0.17474977672100067,
#   'test_accuracy': 0.953181266784668},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:37:27 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '8549f74f-e114-40d0-9a01-31da24c5abdb',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2743013799190521,
#   'training_accuracy': 0.9186000227928162,
#   'test_loss': 0.32854920625686646,
#   'test_accuracy': 0.9021608829498291},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.245705246925354,
#   'training_accuracy': 0.9265000224113464,
#   'test_loss': 0.2952301800251007,
#   'test_accuracy': 0.9075630307197571},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.25864139199256897,
#   'training_accuracy': 0.9229000210762024,
#   'test_loss': 0.31297773122787476,
#   'test_accuracy': 0.9069628119468689},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.24770265817642212,
#   'training_accuracy': 0.9226999878883362,
#   'test_loss': 0.15043699741363525,
#   'test_accuracy': 0.9519807696342468},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.21171745657920837,
#   'training_accuracy': 0.9376999735832214,
#   'test_loss': 0.1669618934392929,
#   'test_accuracy': 0.9543817639350891},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2620786428451538,
#   'training_accuracy': 0.9218000173568726,
#   'test_loss': 0.32964998483657837,
#   'test_accuracy': 0.8967586755752563},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '3c7ad0f1-a881-4284-b46b-99698d75a773',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.26929447054862976,
#   'training_accuracy': 0.9194999933242798,
#   'test_loss': 0.18052993714809418,
#   'test_accuracy': 0.9441776871681213},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.23379497230052948,
#   'training_accuracy': 0.9275000095367432,
#   'test_loss': 0.14202983677387238,
#   'test_accuracy': 0.9549819827079773},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2334006130695343,
#   'training_accuracy': 0.9309999942779541,
#   'test_loss': 0.27742326259613037,
#   'test_accuracy': 0.9129651784896851},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.1990087777376175,
#   'training_accuracy': 0.9416000247001648,
#   'test_loss': 0.15486456453800201,
#   'test_accuracy': 0.9591836929321289},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2570168972015381,
#   'training_accuracy': 0.9236000180244446,
#   'test_loss': 0.1699412614107132,
#   'test_accuracy': 0.9495798349380493},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.24829572439193726,
#   'training_accuracy': 0.9244999885559082,
#   'test_loss': 0.31442543864250183,
#   'test_accuracy': 0.9021608829498291},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:38:29 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '518e8492-622e-41b7-822d-3ab2101d21b1',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.24609804153442383,
#   'training_accuracy': 0.9261000156402588,
#   'test_loss': 0.29726558923721313,
#   'test_accuracy': 0.9069628119468689},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'benign_client1',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2224976271390915,
#   'training_accuracy': 0.9333999752998352,
#   'test_loss': 0.26298919320106506,
#   'test_accuracy': 0.9165666103363037},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'malicious_client2',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.1889679729938507,
#   'training_accuracy': 0.945900022983551,
#   'test_loss': 0.15117107331752777,
#   'test_accuracy': 0.9591836929321289},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'benign_client3',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.2387111634016037,
#   'training_accuracy': 0.9291999936103821,
#   'test_loss': 0.2981027662754059,
#   'test_accuracy': 0.9069628119468689},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'benign_client4',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.24503067135810852,
#   'training_accuracy': 0.9253000020980835,
#   'test_loss': 0.16668732464313507,
#   'test_accuracy': 0.9537814855575562},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'benign_client2',
#   'client_role': 'WORKER',
#   'client_type': 'benign',
#   'training_loss': 0.23494331538677216,
#   'training_accuracy': 0.9301000237464905,
#   'test_loss': 0.28515392541885376,
#   'test_accuracy': 0.9153661727905273},
#  {'model_committed_at': 'Tue, 05 Mar 2024 13:39:00 GMT',
#   'session_id': 'experiment_fedavg_lf_attack',
#   'model': '5702a9fa-705d-4c08-92a7-775fa626f89f',
#   'client_name': 'malicious_client1',
#   'client_role': 'WORKER',
#   'client_type': 'malicious',
#   'training_loss': 0.22151963412761688,
#   'training_accuracy': 0.9323999881744385,
#   'test_loss': 0.13079120218753815,
#   'test_accuracy': 0.958583414554596}]

# %%
graph_data = {
    'training_loss': {
        client: [] for client in set([validation['client_name'] for validation in validations])
    },
    'training_accuracy': {
        client: [] for client in set([validation['client_name'] for validation in validations])
    },
    'test_loss': {
        client: [] for client in set([validation['client_name'] for validation in validations])
    },
    'test_accuracy': {
        client: [] for client in set([validation['client_name'] for validation in validations])
    },
    'overall_training_loss': [],
    'overall_training_accuracy': [],
    'overall_test_loss': [],
    'overall_test_accuracy': []
}

# %%
for validation in validations:
    graph_data['training_loss'][validation['client_name']].append(validation['training_loss'])
    graph_data['training_accuracy'][validation['client_name']].append(validation['training_accuracy'])
    graph_data['test_loss'][validation['client_name']].append(validation['test_loss'])
    graph_data['test_accuracy'][validation['client_name']].append(validation['test_accuracy'])

# %%
graph_data['overall_training_loss'] = [np.mean([graph_data['training_loss'][key][i] for key in graph_data['training_loss'].keys()]) for i in range(num_rounds)]
graph_data['overall_training_accuracy'] = [np.mean([graph_data['training_accuracy'][key][i] for key in graph_data['training_accuracy'].keys()]) for i in range(num_rounds)]
graph_data['overall_test_loss'] = [np.mean([graph_data['test_loss'][key][i] for key in graph_data['test_loss'].keys()]) for i in range(num_rounds)]
graph_data['overall_test_accuracy'] = [np.mean([graph_data['test_accuracy'][key][i] for key in graph_data['test_accuracy'].keys()]) for i in range(num_rounds)]

# %%
# graph_data

# %%
x = range(num_rounds)

for i in range(len(graph_data['training_accuracy'])):
    plt.plot(x, graph_data['training_accuracy'][list(graph_data['training_accuracy'].keys())[i]])
    
plt.plot(x, graph_data['overall_training_accuracy'])
    
plt.legend([label for label in graph_data['training_accuracy'].keys()] + ['overall_training_accuracy'])
plt.show()

# %%
x = range(num_rounds)

for i in range(len(graph_data['test_accuracy'])):
    plt.plot(x, graph_data['test_accuracy'][list(graph_data['test_accuracy'].keys())[i]])
    
plt.plot(x, graph_data['overall_test_accuracy'])
    
plt.legend([label for label in graph_data['test_accuracy'].keys()] + ['overall_test_accuracy'])
plt.show()

# %%
x = range(num_rounds)

for i in range(len(graph_data['test_loss'])):
    plt.plot(x, graph_data['test_loss'][list(graph_data['test_loss'].keys())[i]])
    
plt.plot(x, graph_data['overall_test_loss'])
    
plt.legend([label for label in graph_data['test_loss'].keys()] + ['overall_test_loss'])
plt.show()

# %%
x = range(num_rounds)

for i in range(len(graph_data['training_loss'])):
    plt.plot(x, graph_data['training_loss'][list(graph_data['training_loss'].keys())[i]])
    
plt.plot(x, graph_data['overall_training_loss'])
    
plt.legend([label for label in graph_data['training_loss'].keys()] + ['overall_training_loss'])
plt.show()
